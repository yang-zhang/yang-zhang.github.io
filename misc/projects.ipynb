# %%
import pandas as pd
df = pd.read_csv('/Users/yang.zhang/Downloads/projects.csv', sep=';')

# %%
df.shape
# Out:
# (1048, 3)

# %%
df.head()
# Out:
#                                                title  \
# 0                               Build an Interpreter
# 1  Memory Allocators 101 - Write a simple memory ...
# 2                                 Write a Shell in C
# 3                            Write a FUSE Filesystem
# 4                         Build Your Own Text Editor
#
#                                                  url technology
# 0               http://www.craftinginterpreters.com/      C/C++
# 1  https://arjunsreedharan.org/post/148675821737/...      C/C++
# 2  https://brennan.io/2015/01/16/write-a-shell-in-c/      C/C++
# 3   https://www.cs.nmsu.edu/~pfeiffer/fuse-tutorial/      C/C++
# 4          http://viewsourcecode.org/snaptoken/kilo/      C/C++

# %%
df[df.technology=='Python'].sample(3).T
# Out:
#                                                           98   \
# title        How To Scrape With Python and Selenium WebDriver
# url         http://www.byperth.com/2018/04/25/guide-web-sc...
# technology                                             Python
#
#                                                           175  \
# title          Natural Language Processing using scikit-learn
# url         https://towardsdatascience.com/natural-languag...
# technology                                             Python
#
#                                                           185
# title                                  Build the Game of Life
# url         https://robertheaton.com/2018/07/20/project-2-...
# technology                                             Python

# %%
df.technology.value_counts().to_dict()
# Out:
# {'Arduino': 455,
#  'Python': 120,
#  'C/C++': 104,
#  'Javascript': 26,
#  'React': 24,
#  'JavaScript, HTML5, CSS3': 21,
#  'Golang': 18,
#  'NodeJS': 15,
#  'Rust': 13,
#  'Python, OpenCV, Numpy': 10,
#  'C#': 8,
#  'Java': 8,
#  'HTML5, CSS3': 8,
#  'Angular': 7,
#  'Swift, XCode, iOS': 7,
#  'Haskell': 7,
#  'VueJS': 6,
#  'Ruby': 6,
#  'Clojure': 4,
#  'React, JavaScript, HTML5, CSS3': 4,
#  'Ruby on Rails': 3,
#  'Godot, C#, 2D': 3,
#  'C/C++, 2D': 3,
#  'PHP': 3,
#  '3D, Unity, C#': 3,
#  'Python ': 3,
#  'R': 3,
#  'HTML5, CSS3, JavaScript': 3,
#  'Python, OpenCV, Numpy, C/C++': 3,
#  '2D, Unity, C#': 3,
#  ' PHP': 3,
#  'Scala': 3,
#  'Flutter, Dart, Android, iOS': 2,
#  'React, 2D, JavaScript, HTML5, CSS3': 2,
#  'React, Gatsby, Leaflet': 2,
#  'NextJS, Pusher, Sentiment, Node, React': 2,
#  'Phaser 3, Express, Socket.io, JavaScript': 2,
#  'Python, Matplotlib, Numpy, Pandas': 2,
#  'React, HTML, CSS, JavaScript': 2,
#  'Elixir': 2,
#  'Unity, C#': 2,
# ...

# %%
for ttl,t in zip(df.title,df.technology):
    print(ttl,' -- ',t)
# Out:
# Build an Interpreter  --  C/C++
# Memory Allocators 101 - Write a simple memory allocator  --  C/C++
# Write a Shell in C  --  C/C++
# Write a FUSE Filesystem  --  C/C++
# Build Your Own Text Editor  --  C/C++
# Build Your Own Lisp  --  C/C++
# How to Program an NES Game in C  --  C/C++
# Write an OS from scratch  --  C/C++
# How to create an OS from scratch   --  C/C++
# Building a CHIP-8 Emulator  --  C/C++
# Beginning Game Programming with C++ and SDL  --  C/C++
# Implementing a Key-Value Store  --  C/C++
# Tiny Renderer or how OpenGL works: software rendering in 500 lines of code  --  C/C++
# Understandable RayTracing in 256 lines of bare C++  --  C/C++
# KABOOM! in 180 lines of bare C++  --  C/C++
# 486 lines of C++: old-school FPS in a weekend  --  C/C++
# Writing a minimal x86-64 JIT compiler in C++  --  C/C++
# Build a Live Code-reloader Library for C++  --  C/C++
# Write a hash table in C  --  C/C++
# Let's Build a Simple Database  --  C/C++
# ...
